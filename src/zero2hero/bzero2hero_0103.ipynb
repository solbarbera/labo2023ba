# %% [markdown]
# # Zero to Hero

# %% [markdown]
# ## 1.03  Construyendo un arbol

# %% [markdown]
# Se construye un arbol de decisión, se ven distintas formas de pasar los parámetros y distintas formas de dibujarlo.
# <br>
# Se muestran funcionalidades básicas de0la libreria  *data.table*

# %%
library("data.table") # cargo la libreria  data.table
library("rpart") # cargo la libreria  rpart

# %%
options(repr.plot.width = 25, repr.plot.height = 25) # para que los gráficos me salgan legibles

# %%
setwd("~/buckets/b1/")

# %%
dataset <- fread("./datasets/dataset_pequeno.csv")

# %% [markdown]
# Ahora entreno un arbol de decision
# <br>
# "clase_ternaria ~ ."  significa predecir clase_ternaria utilizando *todo el resto* de las variables del dataset

# %%
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107]
)

# %% [markdown]
# Imprimo el modelo con la muy básica funcion print() de la libreria rpart

# %%
print(modelo)
# Out:
# n= 164682
#
# node), split, n, loss, yval, (yprob)
#       * denotes terminal node
#
# 1) root 164682 2346 CONTINUA (0.006545949 0.007699688 0.985754363) *

# %% [markdown]
# Esta impresión no es gráfica. No me sirve.
# <br>
# a pesar que no me sirve, he encontrado una piedra en el camino, me está generando un arbol con un solo nodo, con solo la raiz

# %% [markdown]
# Busco bibliografía y encuentro que existe la libreria  **rpart.plot** que grafica arboles generados con la libreria  *rpart*

# %%
library("rpart.plot")

# %%
rpart.plot::prp(modelo)
# Out:
# plot without title

# %% [markdown]
# Me ha salido una impresión del arbol, que es un solo nodo, pero solo dice continua.
# <br>
# leo la documentacion de la librería rpart.plot   https://cran.r-project.org/web/packages/rpart.plot/rpart.plot.pdf

# %%
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3)
# Out:
# plot without title

# %% [markdown]
# Ha salido solo la raiz del arbol
# <br>
# Los tres numeros que muestra en el nodo con la cantidad de BAJA+1, BAJA+2 y CONTINUA, en ese orden, alfabetico.
# <br>
# la cantidad de CONTINUA   la está mostrando en notacion científica

# %% [markdown]
# ### cambio hiperparámetros del arbol para salga algo mas que un solo nodo

# %% [markdown]
# El hiperparámetro cp  *complexity*   limita el split de los nodos.
# <br>
# El default es  cp=0.05
# <br>
# Pruebo con cp=0.0  a ver si "se abre el arbol"

# %% [markdown]
# Leo la documentación de la libreria rpart  https://cran.r-project.org/web/packages/rpart/rpart.pdf   y veo que existe un hiperparámetro de la funcion rpart  llamado **xval** que es para hacer cross validation, que por default viene seteado en xval=10 .   No me interesa en este momento que haga cross validation, para evitarlo voy a poner  *xval=0*

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = 0.0
)

# imprimo el modelo graficamente
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3)
# Out:
# Warning message:
# “labs do not fit even at cex 0.15, there may be some overplotting”
# plot without title

# %% [markdown]
# sale un arbol de gran profundidad  que ni se puede visualizar
# <br>
# el mensaje  ""labs do not fit even at cex 0.15, there may be some overplotting"" me dice que no pudo dibujarlo correctamente
# <br>
# lamentablemente me doy cuenta la libreria rpart.plot es mala
# <br>
# establezco  maxdepth=2 para poder apreciarlo

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = 0.0,
    maxdepth = 2
)

# imprimo el modelo graficamente
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.3, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %% [markdown]
# Esperaba ver un albol de profundidad 2 sin embargo, por alguna misteriosa razón, se ha generado un arbol con un solo nodo.
# <br>
# Corto por lo sano,  y establezco  cp=-1  para que siempre se abra el arbol

# %% [markdown]
# #genero el modelo
# modelo < -rpart(formula="clase_ternaria ~ .",
#     data=dataset1,
#     xval=0,
#     cp=-1,
#     maxdepth=3)
#
# #imprimo el modelo graficamentne
# prp(modelo, extra=101, digits=5, branch=1, type=4, varlen=0, faclen=0, tweak=1.3)

# %%
# genero el modelo
modelo <- rpart(
    formula = "clase_ternaria ~ .",
    data = dataset[foto_mes == 202107],
    xval = 0,
    cp = -1,
    maxdepth = 3
)

# imprimo el modelo graficamente
options(repr.plot.width = 40, repr.plot.height = 20)
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.1, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %%
# genero el modelo
dataset2 <- copy(dataset)
julio <- copy(dataset[foto_mes == 202107])
dataset2[foto_mes == 202109, clase_ternaria := "Z01"]
julio[, clase_ternaria := "Z01"]
dataset2 <- rbind(dataset2, julio)
dataset2[, foto_mes := NULL]
setorder(dataset2, clase_ternaria)

modelo <- rpart(
    formula = "clase_ternaria ~ . -Master_fultimo_cierre -Visa_fultimo_cierre -mcomisiones_mantenimiento",
    data = dataset2,
    xval = 0,
    cp = -1,
    maxdepth = 3
)

# imprimo el modelo graficamente
options(repr.plot.width = 40, repr.plot.height = 20)
prp(modelo, extra = 101, digits = -5, branch = 1, type = 4, varlen = 0, faclen = 0, tweak = 1.1, cex = 1.2)
# Out:
# Warning message:
# “cex and tweak both specified, applying both”
# plot without title

# %%
modelo$splits
# Out:
#                                   count  ncat improve      index
# Visa_msaldodolares                472065 -1   1385.3154330      113.780
# mcomisiones                       494601  1   1149.2299667       -0.005
# mcomisiones_otras                 494601  1   1146.3603172       -0.005
# cliente_antiguedad                494601 -1    746.5812048      326.500
# ctarjeta_visa_descuentos          494601  1    734.6939461        0.500
# mtarjeta_visa_consumo              22536 -1      0.8508489   274798.710
# ctarjeta_visa_debitos_automaticos      0 -1      0.8501414       17.500
# ctarjeta_visa_transacciones            0 -1      0.8495186       78.500
# Visa_mpagominimo                       0 -1      0.8492559    83476.545
# Visa_msaldototal                       0 -1      0.8492263   577878.770
# mcomisiones                       423162  1   1136.6528902       -0.005
# mcomisiones_otras                 423162  1   1133.7859471       -0.005
# Visa_mconsumosdolares             362560  1    888.4911533        1.080
# cliente_antiguedad                423162 -1    585.7009990      326.500
# ctarjeta_visa_descuentos          423162  1    534.3528132        0.500
# mcomisiones_otras                      0  1      0.9999480       -0.005
# mcaja_ahorro                           0  1      0.9773302    -5355.350
# mpagodeservicios                       0 -1      0.9773302  3442142.965
# mprestamos_hipotecarios                0 -1      0.9773278 31899393.000
# mextraccion_autoservicio               0 -1      0.9773278  4046850.000
# Visa_mconsumosdolares             355513  1    812.2212437        1.080
# cliente_antiguedad                413566 -1    604.7265178      326.500
# ctarjeta_visa_descuentos          413566  1    487.6209321        0.500
# ctarjeta_master_descuentos        413566  1    462.3699405        0.500
# Master_fechaalta                  370305 -1    419.3358116     7726.000
# Visa_msaldodolares                 36466  1      0.8613468      107.900
# Visa_mconsumospesos                    0 -1      0.8510406       -0.770
# Visa_mconsumototal                     0 -1      0.8510406       -0.770
# Visa_mpagosdolares                     0  1      0.8472545        0.810
# ctarjeta_visa_debitos_automaticos  21587  1      0.8457975       25.500
# ⋮                                 ⋮      ⋮    ⋮            ⋮
# Visa_mpagosdolares                71439   1   832.5268620        1.295
# Visa_msaldodolares                71439   1   494.3338379      220.540
# ctarjeta_visa_descuentos          71439   1   277.9078257        0.500
# ctarjeta_master_descuentos        71439   1   265.2346936        0.500
# Visa_mconsumosdolares             71439   1   190.4566168        5.565
# mcaja_ahorro                          0   1     0.6081412    87293.170
# mpasivos_margen                       0   1     0.5970128     3642.720
# mcuentas_saldo                        0   1     0.5931354   168708.460
# Visa_mlimitecompra                    0   1     0.5829729  1149365.525
# mtransferencias_recibidas             0   1     0.5811112   536350.685
# Visa_msaldodolares                30623  -1   111.8301723      343.825
# ctarjeta_visa_descuentos          30623   1    75.4971498        0.500
# cliente_antiguedad                30623  -1    71.9956372      326.500
# ctarjeta_master_descuentos        30623   1    59.2737395        0.500
# Master_fechaalta                  29577  -1    53.0101715     7726.000
# Visa_mconsumosdolares                 0  -1     0.9123208        3.505
# Visa_mpagosdolares                    0  -1     0.8544885        3.555
# Visa_mconsumospesos                   0  -1     0.7959377      338.980
# Visa_mconsumototal                    0  -1     0.7959377      338.980
# mtarjeta_visa_consumo                 0  -1     0.7894393      342.695
# Visa_msaldodolares                40816   1   386.0548905      557.290
# Visa_mconsumosdolares             40816   1   303.5783573        5.565
# ctarjeta_master_descuentos        40816   1   206.8880779        0.500
# ctarjeta_visa_descuentos          40816   1   161.0857259        0.500
# mtarjeta_master_descuentos        39917   1   120.7728273       11.730
# Visa_mconsumosdolares                 0   1     0.9586437        5.585
# Visa_mpagominimo                      0   1     0.6443307     3677.355
# Visa_mconsumospesos                   0   1     0.6083399     2824.355
# Visa_mpagosdolares                    0  -1     0.6083399        0.915
# Visa_mconsumototal                    0   1     0.6083399     2824.355
#                                   adj
# Visa_msaldodolares                0.0000000000
# mcomisiones                       0.0000000000
# mcomisiones_otras                 0.0000000000
# cliente_antiguedad                0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# mtarjeta_visa_consumo             0.0144178950
# ctarjeta_visa_debitos_automaticos 0.0097425776
# ctarjeta_visa_transacciones       0.0056271784
# Visa_mpagominimo                  0.0038914319
# Visa_msaldototal                  0.0036954605
# mcomisiones                       0.0000000000
# mcomisiones_otras                 0.0000000000
# Visa_mconsumosdolares             0.0000000000
# cliente_antiguedad                0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# mcomisiones_otras                 0.9977073781
# mcaja_ahorro                      0.0003126303
# mpagodeservicios                  0.0003126303
# mprestamos_hipotecarios           0.0002084202
# mextraccion_autoservicio          0.0002084202
# Visa_mconsumosdolares             0.0000000000
# cliente_antiguedad                0.0000000000
# ctarjeta_visa_descuentos          0.0000000000
# ctarjeta_master_descuentos        0.0000000000
# Master_fechaalta                  0.0000000000
# Visa_msaldodolares                0.1011979651
# Visa_mconsumospesos               0.0343890743
# Visa_mconsumototal                0.0343890743
# Visa_mpagosdolares                0.0098462885
# ctarjeta_visa_debitos_automaticos 0.0004011451
# ⋮                                 ⋮
# Visa_mpagosdolares                0.00000000
# Visa_msaldodolares                0.00000000
# ctarjeta_visa_descuentos          0.00000000
# ctarjeta_master_descuentos        0.00000000
# Visa_mconsumosdolares             0.00000000
# mcaja_ahorro                      0.08585050
# mpasivos_margen                   0.05988963
# mcuentas_saldo                    0.05084414
# Visa_mlimitecompra                0.02713647
# mtransferencias_recibidas         0.02279333
# Visa_msaldodolares                0.00000000
# ctarjeta_visa_descuentos          0.00000000
# cliente_antiguedad                0.00000000
# ctarjeta_master_descuentos        0.00000000
# Master_fechaalta                  0.00000000
# Visa_mconsumosdolares             0.58692308
# Visa_mpagosdolares                0.31446154
# Visa_mconsumospesos               0.03861538
# Visa_mconsumototal                0.03861538
# mtarjeta_visa_consumo             0.00800000
# Visa_msaldodolares                0.00000000
# Visa_mconsumosdolares             0.00000000
# ctarjeta_master_descuentos        0.00000000
# ctarjeta_visa_descuentos          0.00000000
# mtarjeta_master_descuentos        0.00000000
# Visa_mconsumosdolares             0.90140763
# Visa_mpagominimo                  0.15209392
# Visa_mconsumospesos               0.06629286
# Visa_mpagosdolares                0.06629286
# Visa_mconsumototal                0.06629286

# %% [markdown]
# ### Disgresión : aprendo a borrar la memoria

# %% [markdown]
# Listo los objetos que estan en la memoria de R en este momento

# %%
ls()
# Out:
# [1] "dataset"  "dataset2" "julio"    "modelo"

# %% [markdown]
# creo una variable a ver que sucede

# %%
a <- 1

# %% [markdown]
# me vuelvo a fijar que objtetos estan en la memoria, deberia aparecer la nueva variable **a**

# %%
ls()
# Out:
# [1] "a"        "dataset"  "dataset2" "julio"    "modelo"

# %% [markdown]
# tal cual esperaba, aparece el nuevo objeto, la variable  **a**

# %% [markdown]
# Me fijo cuanta memoria esta disponible

# %%
gc()
# Out:
#        used      (Mb)  gc trigger (Mb)   max used  (Mb)
# Ncells    775638  41.5   2515598   134.4   3144497  168.0
# Vcells 115189578 878.9 344477745  2628.2 430450551 3284.1

# %% [markdown]
# Borro **TODOS** los objetos que estan en la memoria de R

# %%
rm(list = ls())

# %% [markdown]
# Me vuelvo a fijar cuanta memoria hay disponible

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  774162 41.4   2515598   134.4   3144497  168.0
# Vcells 1664228 12.7 275582196  2102.6 430450551 3284.1

# %% [markdown]
# llama a **gc()** garbaje collection, que me va a liberar mas aún la memoria
# <br>
# https://cran.r-project.org/web/packages/profmem/vignettes/profmem.html

# %% [markdown]
# Ahora si, limpie bore todos los objetos de R y limpie la memoria
